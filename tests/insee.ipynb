# %%
from pynsee.localdata import get_area_list, get_local_data
import pandas as pd

# 1️⃣ Récupérer toutes les zones administratives (forcé update)
areas = get_area_list(update=True)

# 2️⃣ Filtrer uniquement les communes
communes = areas[areas['AREA_TYPE'] == "Commune"]

# 3️⃣ Filtrer les communes d'Île-de-France
# Codes régions IDF : 11
idf_coms = communes[communes['CODE'].str.startswith("75") |  # Paris 
                    communes['CODE'].str.startswith("77") |  # Seine-et-Marne
                    communes['CODE'].str.startswith("78") |  # Yvelines
                    communes['CODE'].str.startswith("91") |  # Essonne
                    communes['CODE'].str.startswith("92") |  # Hauts-de-Seine
                    communes['CODE'].str.startswith("93") |  # Seine-Saint-Denis
                    communes['CODE'].str.startswith("94") |  # Val-de-Marne
                    communes['CODE'].str.startswith("95")]   # Val-d'Oise

# 4️⃣ Extraire la liste des codes INSEE
idf_codes = idf_coms['CODE'].tolist()
print(f"Nombre de communes en IDF : {len(idf_codes)}")
# Out:
# Nombre de communes en IDF : 1285
# ['77001', '77002', '77003', '77004', '77005', '77006', '77007', '77008', '77009', '77010']
# [75011, 75012, 75013, 75014, 75015, 75016, 75017, 75018, 75019, 75020]

# %%
# Récupérer les données socio-professionnelles pour toutes ces communes
idf_data = get_local_data(
    variables="INDICS_FILO_DISP",
    dataset_version="GEO2020FILO2018",
    nivgeo="COM",
    geocodes=idf_codes,
    silent=True
)

idf_data
# Out:
# Getting data: 100%|██████████| 1285/1285 [42:13<00:00,  1.97s/it]
# /opt/python/lib/python3.13/site-packages/pynsee/utils/save_df.py:103: UserWarning: ("Expected bytes, got a 'int' object", 'Conversion failed for column CODEGEO with type object')
# Error, file not saved:
# /home/onyxia/.cache/pynsee/pynsee/06d5d746e0edbc356fd2da561a8c46c5.parquet
#      CODEGEO NIVGEO                 UNIT_label_fr     UNIT INDICS_FILO_DISP  \
# 0      77001    COM     Nombre de ménages fiscaux    NBMEN                1
# 1      77001    COM  Nombre de personnes fiscales   NBPERS                1
# 2      77001    COM                       Médiane  MEDIANE                1
# 3      77002    COM     Nombre de ménages fiscaux    NBMEN                1
# 4      77002    COM  Nombre de personnes fiscales   NBPERS                1
# ...      ...    ...                           ...      ...              ...
# 3778   75016    NaN                           NaN      NaN              NaN
# 3779   75017    NaN                           NaN      NaN              NaN
# 3780   75018    NaN                           NaN      NaN              NaN
# 3781   75019    NaN                           NaN      NaN              NaN
# 3782   75020    NaN                           NaN      NaN              NaN
#
#       OBS_VALUE             INDICS_FILO_DISP_label  DATASET_VERSION  \
# 0         469.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 1        1211.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 2       30030.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 3         303.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 4         788.0  Indicateur de revenus disponibles  GEO2020FILO2018
# ...         ...                                ...              ...
# 3778        NaN                                NaN              NaN
# 3779        NaN                                NaN              NaN
# 3780        NaN                                NaN              NaN
# 3781        NaN                                NaN              NaN
# 3782        NaN                                NaN              NaN
#
#                            DATASET_NAME  DATA_DATE
# 0     Fichier localisé social et fiscal     2018.0
# 1     Fichier localisé social et fiscal     2018.0
# 2     Fichier localisé social et fiscal     2018.0
# 3     Fichier localisé social et fiscal     2018.0
# 4     Fichier localisé social et fiscal     2018.0
# ...                                 ...        ...
# 3778                                NaN        NaN
# 3779                                NaN        NaN
# 3780                                NaN        NaN
# 3781                                NaN        NaN
# 3782                                NaN        NaN
#
# [3783 rows x 10 columns]
#
#   _save_dataframe(df, file_name, silent)
#      CODEGEO NIVGEO                 UNIT_label_fr     UNIT INDICS_FILO_DISP  \
# 0      77001    COM     Nombre de ménages fiscaux    NBMEN                1
# 1      77001    COM  Nombre de personnes fiscales   NBPERS                1
# 2      77001    COM                       Médiane  MEDIANE                1
# 3      77002    COM     Nombre de ménages fiscaux    NBMEN                1
# 4      77002    COM  Nombre de personnes fiscales   NBPERS                1
# ...      ...    ...                           ...      ...              ...
# 3778   75016    NaN                           NaN      NaN              NaN
# 3779   75017    NaN                           NaN      NaN              NaN
# 3780   75018    NaN                           NaN      NaN              NaN
# 3781   75019    NaN                           NaN      NaN              NaN
# 3782   75020    NaN                           NaN      NaN              NaN
#
#       OBS_VALUE             INDICS_FILO_DISP_label  DATASET_VERSION  \
# 0         469.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 1        1211.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 2       30030.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 3         303.0  Indicateur de revenus disponibles  GEO2020FILO2018
# 4         788.0  Indicateur de revenus disponibles  GEO2020FILO2018
# ...         ...                                ...              ...
# 3778        NaN                                NaN              NaN
# 3779        NaN                                NaN              NaN
# 3780        NaN                                NaN              NaN
# 3781        NaN                                NaN              NaN
# 3782        NaN                                NaN              NaN
#
#                            DATASET_NAME  DATA_DATE
# 0     Fichier localisé social et fiscal     2018.0
# 1     Fichier localisé social et fiscal     2018.0
# 2     Fichier localisé social et fiscal     2018.0
# 3     Fichier localisé social et fiscal     2018.0
# 4     Fichier localisé social et fiscal     2018.0
# ...                                 ...        ...
# 3778                                NaN        NaN
# 3779                                NaN        NaN
# 3780                                NaN        NaN
# 3781                                NaN        NaN
# 3782                                NaN        NaN
#
# [3783 rows x 10 columns]

# %%
idf_data.to_excel("idf_data2.xlsx", index=False, engine='openpyxl')
